# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Documents\\IPython Notebooks'

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from dateutil import parser
# %matplotlib inline

pd_1day= pd.read_csv('./RI_1day.txt',header=None, 
                     names=['date','time','o','h','l','c','v'],
                     parse_dates=[['date', 'time']], 
                     index_col='date_time')
pd_1day['return']=pd_1day['c'].diff()/pd_1day['c']*100
pd_1day=pd_1day.drop(pd_1day.index[0])

# %%
pd_1day
# Out:
#                  o       h       l       c        v    return
# date_time
# 2006-01-11  117105  119260  116955  119160    14413  1.560926
# 2006-01-12  119500  123600  119500  122800     7854  2.964169
# 2006-01-13  122605  123500  120760  121500    17760 -1.069959
# 2006-01-16  121900  125550  121370  125550    18321  3.225806
# 2006-01-17  126490  127200  121405  122170    26577 -2.766637
# 2006-01-18  121500  121500  117555  118500    13452 -3.097046
# 2006-01-19  118060  122690  117000  122690    19118  3.415111
# 2006-01-20  124000  126000  123100  125400    17111  2.161085
# 2006-01-23  125000  127455  124100  124550    22307 -0.682457
# 2006-01-24  125200  127530  125200  127400    16626  2.237049
# 2006-01-25  127950  130750  127600  130200    12013  2.150538
# 2006-01-26  129815  131400  128605  130515    23555  0.241352
# 2006-01-27  130725  134200  130725  133910    24237  2.535285
# 2006-01-30  134800  134800  127365  127680    21842 -4.879386
# ...

# %%
frame = 5
pd_1day['num'] = np.arange(0,len(pd_1day.index))
pd_1day['std'] = ''

# %% [raw]
# def calc(df, frame=5):
#     cur_ix = df['num']
#     if cur_ix >= frame:
#         return np.std(df.ix[cur_ix-frame:cur_ix]['return'])
# pd_1day['std'] = pd.apply(pd_1day, calc, axis=1, frame=5)

# %%
pd_1day[:10]
# Out:
#                  o       h       l       c      v    return  num std
# date_time
# 2006-01-11  117105  119260  116955  119160  14413  1.560926    0
# 2006-01-12  119500  123600  119500  122800   7854  2.964169    1
# 2006-01-13  122605  123500  120760  121500  17760 -1.069959    2
# 2006-01-16  121900  125550  121370  125550  18321  3.225806    3
# 2006-01-17  126490  127200  121405  122170  26577 -2.766637    4
# 2006-01-18  121500  121500  117555  118500  13452 -3.097046    5
# 2006-01-19  118060  122690  117000  122690  19118  3.415111    6
# 2006-01-20  124000  126000  123100  125400  17111  2.161085    7
# 2006-01-23  125000  127455  124100  124550  22307 -0.682457    8
# 2006-01-24  125200  127530  125200  127400  16626  2.237049    9
